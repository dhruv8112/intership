# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruv8112/intership/blob/main/ecommerce_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CSV file read

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

df=pd.read_csv('data.csv')

# %% [markdown]
# Data read and print

# %%
print(df.describe())
# Out:
#            Quantity     UnitPrice    CustomerID
# count  25015.000000  25015.000000  16056.000000
# mean       7.260284      7.108481  15572.953288
# std       70.394362    180.950714   1782.224395
# min    -9360.000000      0.000000  12347.000000
# 25%        1.000000      1.450000  14135.000000
# 50%        2.000000      2.510000  15647.500000
# 75%        6.000000      4.250000  17223.000000
# max     2880.000000  13541.330000  18269.000000

# %%
print(df.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# Find the total number of country in Group

# %%
df['Country'].value_counts()
# Out:
# Country
# United Kingdom     23709
# Germany              309
# France               287
# EIRE                 228
# Norway               147
# Portugal              94
# Spain                 45
# Lithuania             35
# Iceland               31
# Italy                 25
# Australia             22
# Denmark               20
# Channel Islands       17
# Japan                 17
# Belgium               12
# Poland                 8
# Switzerland            6
# Netherlands            2
# United                 1
# Name: count, dtype: int64

# %% [markdown]
# Total num of different Country

# %%
print(df['Country'].value_counts().count())
# Out:
# 19

# %%
print(df['Country'].value_counts().index)
# Out:
# Index(['United Kingdom', 'Germany', 'France', 'EIRE', 'Norway', 'Portugal',
#        'Spain', 'Lithuania', 'Iceland', 'Italy', 'Australia', 'Denmark',
#        'Channel Islands', 'Japan', 'Belgium', 'Poland', 'Switzerland',
#        'Netherlands', 'United '],
#       dtype='object', name='Country')

# %% [markdown]
# find the group of cusotmer id so that undeerstand the number of purchase item by customers

# %%
no_of_customer=df['CustomerID'].value_counts()

print(no_of_customer)
# Out:
# CustomerID
# 12748.0    545
# 17850.0    297
# 14911.0    212
# 17841.0    190
# 13174.0    169
#           ...
# 14576.0      1
# 14045.0      1
# 13848.0      1
# 14867.0      1
# 14092.0      1
# Name: count, Length: 654, dtype: int64

# %%
print(no_of_customer.head(20))
# Out:
# CustomerID
# 12748.0    545
# 17850.0    297
# 14911.0    212
# 17841.0    190
# 13174.0    169
# 17341.0    161
# 18118.0    151
# 12433.0    147
# 14667.0    130
# 14606.0    122
# 15574.0    121
# 17059.0    117
# 17827.0    112
# 18041.0    110
# 15061.0    109
# 15311.0    109
# 15880.0    106
# 15514.0    102
# 17920.0     95
# 17340.0     87
# Name: count, dtype: int64

# %% [markdown]
# Total number of Customer Vendor have

# %%
print(df['CustomerID'].nunique())
# Out:
# 654

# %% [markdown]
# Total Highest Spend by the customer

# %%
print(df.groupby('CustomerID')['UnitPrice'].sum().nlargest(1))
# Out:
# CustomerID
# 12748.0    1217.40
# 17850.0    1176.23
# 14911.0    1065.59
# 17841.0     723.58
# 13174.0     519.75
# Name: UnitPrice, dtype: float64

# %% [markdown]
# From where the Customer Belong

# %%
print(df.groupby(['Country','CustomerID'])['UnitPrice'].sum().nlargest(50))
# Out:
# Country         CustomerID
# United Kingdom  12748.0       1217.40
#                 17850.0       1176.23
# EIRE            14911.0       1065.59
# United Kingdom  17841.0        723.58
#                 13174.0        519.75
#                 17340.0        487.52
#                 14667.0        458.24
#                 14606.0        419.03
#                 14030.0        413.75
#                 18118.0        389.71
#                 15498.0        369.67
# France          12567.0        360.40
# United Kingdom  14527.0        348.58
#                 17341.0        343.93
#                 15311.0        308.62
#                 17827.0        305.82
#                 14573.0        304.70
#                 17591.0        297.55
#                 13145.0        295.00
#                 15514.0        293.36
#                 16274.0        286.60
#                 17920.0        268.58
#                 15426.0        260.13
#                 15061.0        254.86
# ...

# %%
import pandas as pd

df=pd.read_csv('/content/data.csv')

print(df.isnull().sum())
# Out:
# InvoiceNo          0
# StockCode          0
# Description      117
# Quantity           0
# InvoiceDate        0
# UnitPrice          1
# CustomerID     12880
# Country            1
# dtype: int64

# %%
import pandas as pd
df['CustomerID'].fillna(0, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# InvoiceNo        0
# StockCode        0
# Description    117
# Quantity         0
# InvoiceDate      0
# UnitPrice        1
# CustomerID       0
# Country          1
# dtype: int64

# %%
df['Description'].fillna('Not Found', inplace=True)

# %%
print(df.isnull().sum())
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      1
# CustomerID     0
# Country        1
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
# prompt: update csv now all nul value  replace by abive

df.to_csv('data.csv', index=False)
print(df.isnull().sum())
print(df.head())
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26      2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26      3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26      2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26      3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26      3.39     17850.0  United Kingdom

# %%
import pandas as pd
df = pd.read_csv('/content/data.csv')
print(df[['InvoiceDate', 'Time']])
# Out:
#            InvoiceDate      Time
# 0      12 January 2010  08:26:00
# 1      12 January 2010  08:26:00
# 2      12 January 2010  08:26:00
# 3      12 January 2010  08:26:00
# 4      12 January 2010  08:26:00
# ...                ...       ...
# 37304       12/17/2010  17:23:00
# 37305       12/17/2010  17:23:00
# 37306       12/17/2010  17:23:00
# 37307       12/17/2010  17:23:00
# 37308         12/17/20       NaN
#
# [37309 rows x 2 columns]

# %%
import pandas as pd
df = pd.read_csv('/content/data - Copy.csv', encoding='latin1')

# %%
# prompt: count negative column in quantity

negative_quantity_count = df['Quantity'].lt(0).sum()
print(f"Number of negative quantity values: {negative_quantity_count}")
# Out:
# Number of negative quantity values: 1666

# %%
# prompt: count negative column in quantity

df['Quantity']=df['Quantity'].abs()

# %%
negative_value=df['Quantity'].lt(0).sum()
print(negative_value)
# Out:
# 0

# %%
most_customers_by_time = df.groupby(['InvoiceDate','Time'])['CustomerID'].count().sort_values(ascending=False)
print(most_customers_by_time.head(1))
# Out:
# InvoiceDate       Time
# 02-02-2011 00:00  17:06:00    259
# Name: CustomerID, dtype: int64

# %%
print(most_customers_by_time.head(30))
# Out:
# InvoiceDate       Time
# 02-02-2011 00:00  17:06:00    259
# 01-06-2011 00:00  16:41:00    171
# 12-05-2010 00:00  16:24:00    169
# 12-08-2010 00:00  12:46:00    161
# 01-05-2011 00:00  15:56:00    157
# 01-07-2011 00:00  12:28:00    149
# 12-06-2010 00:00  12:55:00    137
# 12-12-2010 00:00  16:14:00    137
# 1/25/2011         13:38       137
# 01-07-2011 00:00  14:31:00    131
# 12-02-2010 00:00  15:46:00    121
# 12-05-2010 00:00  12:13:00    120
#                   13:55:00    119
# 12-12-2010 00:00  13:32:00    118
# 12-05-2010 00:00  12:35:00    117
# 02-01-2011 00:00  14:01:00    115
# 1/26/2011         11:27       110
# 1/25/2011         13:26       110
# 12-05-2010 00:00  15:12:00    108
# 1/21/2011         11:18       106
# 1/20/2011         15:22       106
# 12-06-2010 00:00  11:26:00    105
# 12-05-2010 00:00  13:00:00    105
# 01-06-2011 00:00  12:31:00    104
# 1/23/2011         13:31       103
# 1/21/2011         13:07       101
# 1/19/2011         09:05       101
# ...

# %%
most_customers_by_time = df.groupby(['Time'])['CustomerID'].count().sort_values(ascending=False)
print(most_customers_by_time.head(10))
# Out:
# Time
# 13:38       300
# 15:56:00    299
# 16:41:00    276
# 13:31       262
# 17:06:00    260
# 12:44:00    235
# 14:31:00    235
# 12:28:00    232
# 12:31:00    226
# 12:35:00    223
# Name: CustomerID, dtype: int64

# %%
most_customers_by_time = df.groupby(['InvoiceDate','Country',])['CustomerID'].count().sort_values(ascending=False)
print(most_customers_by_time.head(10))
# Out:
# InvoiceDate       Country
# 12-05-2010 00:00  United Kingdom    2492
# 12-02-2010 00:00  United Kingdom    2029
# 12-06-2010 00:00  United Kingdom    1915
# 12-08-2010 00:00  United Kingdom    1866
# 12-01-2010 00:00  United Kingdom    1809
# 12/16/2010        United Kingdom    1662
# 12/14/2010        United Kingdom    1604
# 12-09-2010 00:00  United Kingdom    1566
# 12-12-2010 00:00  United Kingdom    1400
# 12-10-2010 00:00  United Kingdom    1320
# Name: CustomerID, dtype: int64

# %%
most_customers_by_time = df.groupby(['InvoiceDate','Country','Time'])['CustomerID'].count().sort_values(ascending=False)
print(most_customers_by_time.head(10))
# Out:
# InvoiceDate       Country         Time
# 02-02-2011 00:00  United Kingdom  17:06:00    259
# 01-06-2011 00:00  United Kingdom  16:41:00    171
# 12-05-2010 00:00  United Kingdom  16:24:00    169
# 12-08-2010 00:00  United Kingdom  12:46:00    161
# 01-05-2011 00:00  United Kingdom  15:56:00    157
# 01-07-2011 00:00  Germany         12:28:00    149
# 12-06-2010 00:00  United Kingdom  12:55:00    137
# 12-12-2010 00:00  United Kingdom  16:14:00    137
# 1/25/2011         United Kingdom  13:38       137
# 01-07-2011 00:00  United Kingdom  14:31:00    131
# Name: CustomerID, dtype: int64

# %%
mean_customer=df.groupby('CustomerID')['UnitPrice'].mean()
print(mean_customer)
# Out:
# CustomerID
# 12346.0     1.040000
# 12347.0     2.712667
# 12348.0     3.983043
# 12350.0     3.841176
# 12356.0     3.171667
#              ...
# 18259.0     3.157143
# 18260.0     3.220250
# 18269.0     3.387500
# 18277.0    12.750000
# 18283.0     1.805882
# Name: UnitPrice, Length: 1452, dtype: float64

# %%
mean_customer_country = df.groupby(['CustomerID','Country'])['UnitPrice'].mean()
print(mean_customer_country)
# Out:
# CustomerID  Country
# 12346.0     United Kingdom     1.040000
# 12347.0     Iceland            2.712667
# 12348.0     Finland            3.983043
# 12350.0     Norway             3.841176
# 12356.0     Portugal           3.171667
#                                 ...
# 18259.0     United Kingdom     3.157143
# 18260.0     United Kingdom     3.220250
# 18269.0     United Kingdom     3.387500
# 18277.0     United Kingdom    12.750000
# 18283.0     United Kingdom     1.805882
# Name: UnitPrice, Length: 1453, dtype: float64

# %%
import pandas as pd
df = pd.read_csv('/content/data - Copy.csv', encoding='latin1')

# %%
print(df['total sales'])
# Out:
# 0          15.30
# 1          20.34
# 2          22.00
# 3          20.34
# 4          20.34
#            ...
# 112940    125.00
# 112941    125.00
# 112942     -1.95
# 112943     -9.95
# 112944       NaN
# Name: total sales, Length: 112945, dtype: float64

# %%
df['total sales'].abs()
# Out:
# 0          15.30
# 1          20.34
# 2          22.00
# 3          20.34
# 4          20.34
#            ...
# 112940    125.00
# 112941    125.00
# 112942      1.95
# 112943      9.95
# 112944       NaN
# Name: total sales, Length: 112945, dtype: float64

# %%
df['total sales'].fillna(0, inplace=True)
print(df['total sales'].isnull().sum())
# Out:
# 0

# %%
df['total sales'].sum()
# Out:
# 1946215.4899999998

# %%
country_sale=df.groupby('Country')['total sales'].sum()
print(country_sale)
# Out:
# Country
# Australia                 41208.42
# Austria                     941.44
# Bahrain                       0.00
# Belgium                    6094.40
# Channel Islands            3622.16
# Cyprus                     6151.87
# Czech Republic              549.26
# Denmark                    1680.72
# EIRE                      44077.05
# Finland                    6956.20
# France                    37533.61
# Germany                   42288.85
# Greece                     3048.55
# Hong Kong                  2439.76
# Iceland                    1187.18
# Israel                      931.50
# Italy                      3870.99
# Japan                     13302.42
# Lebanon                    1693.88
# Lithuania                  1661.06
# Netherlands               58327.75
# Norway                     4562.37
# Poland                     1465.43
# Portugal                   7592.13
# Saudi Arabia                131.17
# Singapore                  2053.07
# ...

# %%
total_sales_country_customer = df.groupby(['Country', 'CustomerID'])['total sales'].sum()
print(total_sales_country_customer)
# Out:
# Country         CustomerID
# Australia       12386.0         401.90
#                 12388.0         555.35
#                 12393.0         639.50
#                 12415.0       37674.04
#                 12422.0         238.50
#                                 ...
# United Kingdom  18260.0         769.52
#                 18269.0         138.90
#                 18277.0         -12.75
#                 18280.0         180.60
#                 18283.0         317.90
# Name: total sales, Length: 1855, dtype: float64

# %%
df['total sales'].abs()
# Out:
# 0          15.30
# 1          20.34
# 2          22.00
# 3          20.34
# 4          20.34
#            ...
# 112940    125.00
# 112941    125.00
# 112942      1.95
# 112943      9.95
# 112944      0.00
# Name: total sales, Length: 112945, dtype: float64

# %%
total_sales_country_customer = df.groupby(['Country', 'CustomerID'])['total sales'].sum().abs()
print(total_sales_country_customer)
# Out:
# Country         CustomerID
# Australia       12386.0         401.90
#                 12388.0         555.35
#                 12393.0         639.50
#                 12415.0       37674.04
#                 12422.0         238.50
#                                 ...
# United Kingdom  18260.0         769.52
#                 18269.0         138.90
#                 18277.0          12.75
#                 18280.0         180.60
#                 18283.0         317.90
# Name: total sales, Length: 1855, dtype: float64

# %%
mean_of_sales = df.groupby(['Country'])['total sales'].mean()
print(mean_of_sales)
# Out:
# Country
# Australia               122.280178
# Austria                  27.689412
# Bahrain                   0.000000
# Belgium                  18.868111
# Channel Islands          36.960816
# Cyprus                   24.030742
# Czech Republic           36.617333
# Denmark                  42.018000
# EIRE                     39.566472
# Finland                  29.727350
# France                   22.802922
# Germany                  23.108661
# Greece                   56.454630
# Hong Kong                42.802807
# Iceland                  19.786333
# Israel                   29.109375
# Italy                    20.700481
# Japan                    74.732697
# Lebanon                  37.641778
# Lithuania                47.458857
# Netherlands             118.552337
# Norway                   24.012474
# Poland                   24.023443
# Portugal                 25.391739
# Saudi Arabia             13.117000
# Singapore                36.661964
# ...

# %%
std_dev = df.groupby(['Country'])['total sales'].std()
print(std_dev)
# Out:
# Country
# Australia               146.994086
# Austria                  22.752436
# Bahrain                 290.960298
# Belgium                  13.044535
# Channel Islands          57.225353
# Cyprus                   40.918117
# Czech Republic           15.015114
# Denmark                  43.386803
# EIRE                    117.206400
# Finland                  45.837086
# France                   33.037641
# Germany                  36.090358
# Greece                   44.778305
# Hong Kong                36.829139
# Iceland                  11.052495
# Israel                   52.964462
# Italy                    18.888843
# Japan                   287.688431
# Lebanon                  29.117840
# Lithuania                23.824265
# Netherlands             113.492844
# Norway                   54.717766
# Poland                   19.994039
# Portugal                 29.589867
# Saudi Arabia             10.861336
# Singapore                37.418455
# ...

# %%
### baki che karvano

import matplotlib.pyplot as plt

# Extract data from the DataFrame
countries = mean_of_sales.index.to_list()
mean_values = mean_of_sales.values
std_dev_values = std_dev.values

# Create the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create the first bar chart for mean values
ax.bar(countries, mean_values, label="Mean Sales", color="skyblue", alpha=1.0)

# Create the second bar chart for standard deviation values
ax.bar(countries, std_dev_values, label="Standard Deviation", color="coral", alpha=0.5)

# Add labels and title
ax.set_xlabel("Countries")
ax.set_ylabel("Sales")
ax.set_title("Comparison of Mean Sales and Standard Deviation by Country")

# Add legend and show the plot
ax.legend()
plt.xticks(rotation=90, ha="right")
plt.tight_layout()
plt.show()

# %%
df['total sales'].std()
# Out:
# 272.47212258166303

# %%
df['UnitPrice'].std()
# Out:
# 96.75985306117938

# %%
df['total sales'].var()
# Out:
# 74241.05758415679

# %%
coutnryGroup=df.groupby(['Country'])['total sales'].var()
print(coutnryGroup)
# Out:
# Country
# Australia                25284.486198
# Austria                   1195.730649
# Bahrain                   5448.851078
# Belgium                    242.856629
# Brazil                    1082.165400
# Canada                    3735.318169
# Channel Islands           1582.792803
# Cyprus                    1161.355513
# Czech Republic             691.826965
# Denmark                   5219.266168
# EIRE                      9021.868370
# European Community         132.577884
# Finland                   2417.613857
# France                   13731.584494
# Germany                   1393.142612
# Greece                    1324.228600
# Hong Kong                97471.217050
# Iceland                    542.419550
# Israel                    1274.972187
# Italy                      477.449677
# Japan                    96987.331250
# Lebanon                    847.848610
# Lithuania                  567.595599
# Malta                     2051.949636
# ...

# %%
# prompt: find a median

median_sales = df['total sales'].median()
print(f"Median sales: {median_sales}")
# Out:
# Median sales: 0.58

# %%
df['Quantity'].sum()
# Out:
# 5176450.0

# %%
product_quanttty_total=df.groupby(['Description'])['Quantity'].sum()
print(product_quanttty_total)
# Out:
# Description
#  4 PURPLE FLOCK DINNER CANDLES     144.0
#  50'S CHRISTMAS GIFT BAG LARGE    1913.0
#  DOLLY GIRL BEAKER                2448.0
#  I LOVE LONDON MINI BACKPACK       389.0
#  I LOVE LONDON MINI RUCKSACK         1.0
#                                    ...
# wrongly marked carton 22804       -256.0
# wrongly marked. 23343 in box     -3100.0
# wrongly sold (22719) barcode       170.0
# wrongly sold as sets              -600.0
# wrongly sold sets                 -975.0
# Name: Quantity, Length: 4223, dtype: float64

# %%
negative_quantity_count = df['Quantity'].lt(0).sum()
print(f"Number of negative quantity values: {negative_quantity_count}")
# Out:
# Number of negative quantity values: 10624

# %%
# prompt: convert quatity into positive

df['Quantity']=df['Quantity'].abs()

# %%
negative_quantity_count = df['Quantity'].lt(0).sum()
print(f"Number of negative quantity values: {negative_quantity_count}")
# Out:
# Number of negative quantity values: 0

# %%
product_quanttty_total=df.groupby(['Description' , 'Country'])['Quantity'].sum()
print(product_quanttty_total.head(10))
# Out:
# Description                     Country
#  4 PURPLE FLOCK DINNER CANDLES  EIRE                 6.0
#                                 United Kingdom     138.0
#  50'S CHRISTMAS GIFT BAG LARGE  EIRE                48.0
#                                 France              12.0
#                                 Germany             60.0
#                                 Portugal            56.0
#                                 Spain               12.0
#                                 United Kingdom    1729.0
#  DOLLY GIRL BEAKER              Australia          200.0
#                                 Austria             12.0
# Name: Quantity, dtype: float64

# %%
product_quanttty_total=df.groupby(['Description' , 'Country'])['Quantity'].mean()
print(product_quanttty_total)
# Out:
# Description                     Country
#  4 PURPLE FLOCK DINNER CANDLES  EIRE                 6.00
#                                 United Kingdom       3.45
#  50'S CHRISTMAS GIFT BAG LARGE  EIRE                48.00
#                                 France              12.00
#                                 Germany             12.00
#                                                    ...
# wrongly marked carton 22804     United Kingdom     256.00
# wrongly marked. 23343 in box    United Kingdom    3100.00
# wrongly sold (22719) barcode    United Kingdom     170.00
# wrongly sold as sets            United Kingdom     600.00
# wrongly sold sets               United Kingdom     975.00
# Name: Quantity, Length: 20176, dtype: float64

# %%
product_quanttty_total=df.groupby(['Description' , 'Country','CustomerID'])['Quantity'].sum()
print(product_quanttty_total.head(10))
# Out:
# Description                     Country         CustomerID
#  4 PURPLE FLOCK DINNER CANDLES  EIRE            14156.0        6.0
#                                 United Kingdom  12937.0        1.0
#                                                 12940.0        1.0
#                                                 12953.0        6.0
#                                                 13949.0       12.0
#                                                 14071.0        1.0
#                                                 14083.0        2.0
#                                                 14725.0        5.0
#                                                 15012.0        2.0
#                                                 15105.0        6.0
# Name: Quantity, dtype: float64

# %%
product_quanttty_total=df.groupby(['Description' , 'Country'])['Quantity'].std()
print(product_quanttty_total)
# Out:
# Description                     Country
#  4 PURPLE FLOCK DINNER CANDLES  EIRE                   NaN
#                                 United Kingdom    3.862708
#  50'S CHRISTMAS GIFT BAG LARGE  EIRE                   NaN
#                                 France                 NaN
#                                 Germany           0.000000
#                                                     ...
# wrongly marked carton 22804     United Kingdom         NaN
# wrongly marked. 23343 in box    United Kingdom         NaN
# wrongly sold (22719) barcode    United Kingdom         NaN
# wrongly sold as sets            United Kingdom         NaN
# wrongly sold sets               United Kingdom         NaN
# Name: Quantity, Length: 20176, dtype: float64

# %%
product_quanttty_count=df.groupby(['CustomerID'])['Quantity'].count().sort_values(ascending=False)
print(product_quanttty_count)
# Out:
# CustomerID
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 14119.0       1
# 13747.0       1
# 15590.0       1
# 15562.0       1
# 17925.0       1
# Name: Quantity, Length: 4372, dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# DATE 16-05-2024

# %%
df.describe()
# Out:
#             Quantity      UnitPrice    total sales     CustomerID
# count  406829.000000  406829.000000  406829.000000  406829.000000
# mean       13.412279       3.460471      20.401854   15287.690570
# std       248.624170      69.315162     427.591718    1713.600303
# min         1.000000       0.000000 -168469.600000   12346.000000
# 25%         2.000000       1.250000       4.200000   13953.000000
# 50%         5.000000       1.950000      11.100000   15152.000000
# 75%        12.000000       3.750000      19.500000   16791.000000
# max     80995.000000   38970.000000  168469.600000   18287.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Quantity'].plot(kind='hist', bins=20, title='Quantity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/data - Copy.csv' , encoding='latin1')
# Out:
# <ipython-input-2-d5d97f08d773>:2: DtypeWarning: Columns (0,1,2,4,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/sample_data/data - Copy.csv' , encoding='latin1')

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES       2.0
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER       6.0
# 7    536366     22633               HAND WARMER UNION JACK       6.0
# 8    536366     22632            HAND WARMER RED POLKA DOT       6.0
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT      32.0
#
#   InvoiceDate      Time  UnitPrice  total sales  CustomerID         Country
# 0   12-Jan-10  08:26:00       2.55        15.30     17850.0  United Kingdom
# ...

# %%
negative_quantity_count = df['Quantity'].lt(0).sum()
print(f"Number of negative quantity values: {negative_quantity_count}")
# Out:
# Number of negative quantity values: 0

# %%
negative_sales = df['total sales'].lt(0).sum()
print(negative_sales)
# Out:
# 0

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/data - Copy.csv' , encoding='latin1')
# Out:
# <ipython-input-30-d5d97f08d773>:2: DtypeWarning: Columns (0,1,2,4,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/sample_data/data - Copy.csv' , encoding='latin1')

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Convert the datetime format to dd-mm-yy
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime('%d-%m-%y')
# Out:
# <ipython-input-36-f2f96d86bea5>:6: DtypeWarning: Columns (0,1,2,4,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/sample_data/data - Copy.csv', encoding='latin1')
# <ipython-input-36-f2f96d86bea5>:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...

# %%
print(df['InvoiceDate'])
# Out:
# 0          12-01-10
# 1          12-01-10
# 2          12-01-10
# 3          12-01-10
# 4          12-01-10
#              ...
# 1048570         NaN
# 1048571         NaN
# 1048572         NaN
# 1048573         NaN
# 1048574         NaN
# Name: InvoiceDate, Length: 1048575, dtype: object

# %% [markdown]
# Custom Time And Date records

# %%
# Convert 'InvoiceDate' to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

start_date = '12-01-2010'
end_date = '12-02-2010'


# Filter the DataFrame based on the custom range
custom_range_data = df[(df['InvoiceDate'] >= start_date ) &
                       (df['InvoiceDate'] <= end_date)]

print(custom_range_data)
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1       536365     71053                  WHITE METAL LANTERN       6.0
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...        ...       ...                                  ...       ...
# 5212    536846     20983   12 PENCILS TALL TUBE RED RETROSPOT       4.0
# 5213    536846     20974          12 PENCILS SMALL TUBE SKULL       1.0
# 5214    536846     22502           PICNIC BASKET WICKER SMALL       1.0
# 5215    536846     22766                  PHOTO FRAME CORNICE       2.0
# 5216    536846     22617           BAKING SET SPACEBOY DESIGN       2.0
#
#      InvoiceDate      Time  UnitPrice  total sales  CustomerID         Country
# ...

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

start_date = '12-01-2010'
end_date = '12-02-2010'
start_time = '08:26:00'
end_time = '9:00:00'

customrange_dt = df[(df['InvoiceDate'] >= start_date + ' ' + start_time) &
                       (df['InvoiceDate'] <= end_date + ' ' + end_time)]

print(customrange_dt)

# %%
print(custom_range_data['total sales'].mean())
print(custom_range_data['UnitPrice'].count())
# Out:
# 20.81186505654591
# 5217

# %%
custom_range_data_by_country = custom_range_data.groupby('Country')
print(custom_range_data_by_country['total sales'].mean())
# Out:
# Country
# Australia         25.589286
# EIRE              24.390833
# France            42.793000
# Germany           13.564146
# Netherlands       96.300000
# Norway            26.289589
# United Kingdom    20.644089
# Name: total sales, dtype: float64

# %%
plt.plot(custom_range_data_by_country['total sales'].mean())


plt.xlabel('Country')
plt.ylabel('Total Sales')
plt.title('Custom Range Data by Country')
plt.xticks(rotation=90)

plt.show()

# %%
country_mean = df.groupby('Country')['total sales'].mean()
print(country_mean)
# Out:
# Country
# Australia               111.171843
# Austria                  25.543741
# Bahrain                  50.520000
# Belgium                  20.049164
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.459881
# Cyprus                   22.885000
# Czech Republic           31.525333
# Denmark                  49.209614
# EIRE                     37.046254
# European Community       21.454918
# Finland                  32.756000
# France                   25.946748
# Germany                  24.858986
# Greece                   32.948767
# Hong Kong                73.842222
# Iceland                  23.681319
# Israel                   28.157239
# Italy                    22.510548
# Japan                   110.313184
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    23.194567
# Netherlands             120.721695
# Norway                   34.224144
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(country_mean.index, country_mean.values, label='Country Mean', color='Black', alpha=0.5)
ax.plot(custom_range_data_by_country['total sales'].mean().index, custom_range_data_by_country['total sales'].mean().values, label=' 12-01-2010 to 12-02-2010', color='blue', alpha=1)
ax.set_xlabel("Country")
ax.set_ylabel("Total Sales")
ax.set_title("Comparison of Country Mean and Custom Range Mean")

ax.legend()
plt.xticks(rotation=90, ha="right")
plt.tight_layout()
plt.show()

# %%
countries = df['InvoiceDate'].unique()

for country in countries:
  print(country)
# Out:
# 2010-12-01 00:00:00
# 2010-12-02 00:00:00
# 2010-12-03 00:00:00
# 2010-12-05 00:00:00
# 2010-12-06 00:00:00
# 2010-12-07 00:00:00
# 2010-12-08 00:00:00
# 2010-12-09 00:00:00
# 2010-12-10 00:00:00
# 2010-12-12 00:00:00
# 2010-12-13 00:00:00
# 2010-12-14 00:00:00
# 2010-12-15 00:00:00
# 2010-12-16 00:00:00
# 2010-12-17 00:00:00
# 2010-12-19 00:00:00
# 2010-12-20 00:00:00
# 2010-12-21 00:00:00
# 2010-12-22 00:00:00
# 2010-12-23 00:00:00
# 2011-01-04 00:00:00
# 2011-01-05 00:00:00
# 2011-01-06 00:00:00
# 2011-01-07 00:00:00
# 2011-01-09 00:00:00
# 2011-01-10 00:00:00
# 2011-01-11 00:00:00
# 2011-01-12 00:00:00
# 2011-01-13 00:00:00
# 2011-01-14 00:00:00
# 2011-01-16 00:00:00
# 2011-01-17 00:00:00
# 2011-01-18 00:00:00
# 2011-01-19 00:00:00
# 2011-01-20 00:00:00
# 2011-01-21 00:00:00
# 2011-01-23 00:00:00
# 2011-01-24 00:00:00
# 2011-01-25 00:00:00
# 2011-01-26 00:00:00
# 2011-01-27 00:00:00
# 2011-01-28 00:00:00
# 2011-01-30 00:00:00
# 2011-01-31 00:00:00
# 2011-02-01 00:00:00
# ...

# %%
high_volume=df.groupby(['Country', 'Time'])['Time'].count()
print(high_volume)
# Out:
# Country      Time
# Australia    08:51       97
#              09:13       13
#              09:14       17
#              09:31:00    27
#              09:32:00     5
#                          ..
# Unspecified  15:25        9
#              15:31:00    47
#              16:06       83
#              16:21       51
#              16:26:00    72
# Name: Time, Length: 3498, dtype: int64

# %%
custom_range_data_by_country = custom_range_data.groupby('Country')
print(custom_range_data_by_country['total sales'].std())
# Out:
# Country
# Australia          11.883022
# EIRE               14.252776
# France             24.577231
# Germany             6.189124
# Netherlands       114.975563
# Norway             19.538816
# United Kingdom     62.053449
# Name: total sales, dtype: float64

# %% [markdown]
# 3 month quater

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])
start_date='12-01-2010'

end_date='12-03-2010'
custom_range_data=df[(df['InvoiceDate']>=start_date) & (df['InvoiceDate']<=end_date)]
print(custom_range_data)
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1       536365     71053                  WHITE METAL LANTERN       6.0
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...        ...       ...                                  ...       ...
# 7414    537036     84879        ASSORTED COLOUR BIRD ORNAMENT       8.0
# 7415    537036     22943  CHRISTMAS LIGHTS 10 VINTAGE BAUBLES       1.0
# 7416    537036     22837           HOT WATER BOTTLE BABUSHKA        5.0
# 7417    537036    35004C      SET OF 3 COLOURED  FLYING DUCKS       1.0
# 7418    537036    85135C             RED DRAGONFLY HELICOPTER       1.0
#
#      InvoiceDate      Time  UnitPrice  total sales  CustomerID         Country
# ...

# %%
print(custom_range_data['total sales'].min())
print(custom_range_data['total sales'].max())
# Out:
# 0.0
# 1627.2

# %%
country_by = custom_range_data.groupby('Country')['total sales'].min()

# Print the results
print(country_by)
# Out:
# Country
# Australia         15.00
# Belgium            8.50
# EIRE               3.25
# France             5.04
# Germany            1.45
# Italy              9.90
# Netherlands       15.00
# Norway             5.04
# Poland            11.60
# Portugal          15.00
# Spain             99.00
# Switzerland       15.90
# United Kingdom     0.00
# Name: total sales, dtype: float64

# %%
country_by = custom_range_data.groupby('Country')['total sales'].min()

print(country_by)
# Create a bar chart of total sales by country
colors = ['red' if value < 7 else 'green' for value in country_by.values]
country_by.plot(kind='bar', alpha=0.5, color=colors)


# Add title and labels
plt.title('Total Min Sales by Country')
plt.xlabel('Country')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
# Show the plot
plt.show()
# Out:
# Country
# Australia         15.00
# Belgium            8.50
# EIRE               3.25
# France             5.04
# Germany            1.45
# Italy              9.90
# Netherlands       15.00
# Norway             5.04
# Poland            11.60
# Portugal          15.00
# Spain             99.00
# Switzerland       15.90
# United Kingdom     0.00
# Name: total sales, dtype: float64

# %%
country_max=custom_range_data.groupby('Country')['total sales'].max()
print(country_max)
# Out:
# Country
# Australia           51.00
# Belgium             50.40
# EIRE               230.40
# France              90.00
# Germany             68.00
# Italy               56.00
# Netherlands        177.60
# Norway             101.76
# Poland              81.60
# Portugal            28.00
# Spain              145.00
# Switzerland         88.50
# United Kingdom    1627.20
# Name: total sales, dtype: float64

# %%
country_max.plot(kind='bar')
plt.xlabel('Country name')
plt.ylabel('Values')
plt.xticks(rotation=90)
plt.show()

# %%
country_max=custom_range_data.groupby('Country')['total sales'].sum().tail(2)
print(country_max)
# Out:
# Country
# Switzerland          303.40
# United Kingdom    146740.08
# Name: total sales, dtype: float64

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])
start_date='12-04-2010'

end_date='12-09-2010'
custom_range_four_data=df[(df['InvoiceDate']>=start_date) & (df['InvoiceDate']<=end_date)]
print(custom_range_four_data)
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 7419     537037     22114    HOT WATER BOTTLE TEA AND SYMPATHY       8.0
# 7420     537037     21485     RETROSPOT HEART HOT WATER BOTTLE       6.0
# 7421     537037     22835      HOT WATER BOTTLE I AM SO POORLY       3.0
# 7422     537037    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# 7423     537037    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# ...         ...       ...                                  ...       ...
# 22518    538171     22271                 FELTCRAFT DOLL ROSIE       2.0
# 22519    538171     22750         FELTCRAFT PRINCESS LOLA DOLL       1.0
# 22520    538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL       1.0
# 22521    538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG       2.0
# 22522    538171     21931               JUMBO STORAGE BAG SUKI       2.0
#
#       InvoiceDate      Time  UnitPrice  total sales  CustomerID  \
# ...

# %%
print(custom_range_four_data['total sales'].mean())
print(custom_range_four_data['total sales'].min())
print(custom_range_four_data['total sales'].max())
# Out:
# 22.734003575211865
# 0.0
# 13541.33

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format="%m-%d-%Y", errors='coerce')
min_year = df['InvoiceDate'].dt.year.min()
max_year = df['InvoiceDate'].dt.year.max()
print(f"Minimum year: {min_year}")
print(f"Maximum year: {max_year}")
# Out:
# Minimum year: 2010.0
# Maximum year: 2011.0

# %%
import pandas as pd
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format="%m-%d-%Y", errors='coerce')
min_year = df['InvoiceDate'].dt.year.min()
max_year = df['InvoiceDate'].dt.year.max()
print(f"Minimum year: {min_year}")
print(f"Maximum year: {max_year}")
# Out:
# Minimum year: 1.0
# Maximum year: 12.0

# %%
country_group_australia = df[df['Country'] == 'Australia']
print(country_group_australia)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 197       536389     22941        CHRISTMAS LIGHTS 10 REINDEER       6.0
# 198       536389     21622    VINTAGE UNION JACK CUSHION COVER       8.0
# 199       536389     21791  VINTAGE HEADS AND TAILS CARD GAME       12.0
# 200       536389    35004C     SET OF 3 COLOURED  FLYING DUCKS       6.0
# 201       536389    35004G          SET OF 3 GOLD FLYING DUCKS       4.0
# ...          ...       ...                                 ...       ...
# 365445    568708     22175                   PINK OWL SOFT TOY       6.0
# 365446    568708     20971    PINK BLUE FELT CRAFT TRINKET BOX      12.0
# 365447    568708     23391         I LOVE LONDON MINI BACKPACK       4.0
# 365448    568708     23390            DOLLY GIRL MINI BACKPACK       4.0
# 365449    568708     23389              SPACEBOY MINI BACKPACK       8.0
#
#        InvoiceDate      Time  UnitPrice  total sales  CustomerID    Country
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/data - Copy.csv', encoding='latin1')

print(country_group_australia.isnull().sum())
# Out:
# <ipython-input-36-835eec1d99ce>:2: DtypeWarning: Columns (0,1,2,4,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/data - Copy.csv', encoding='latin1')
# InvoiceNo        0
# StockCode        0
# Description      0
# Quantity         0
# InvoiceDate    817
# Time             0
# UnitPrice        0
# total sales      0
# CustomerID       0
# Country          0
# dtype: int64

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min=custom_range_four_data.groupby('Country')['total sales'].min()
print(country_four_min)
country_four_max=custom_range_four_data.groupby('Country')['total sales'].max()
print(country_four_max)
country_four_sum=custom_range_four_data.groupby('Country')['total sales'].sum().tail(2)
print(country_four_sum)
# Out:
# Country
# Australia          17.70
# Channel Islands    14.85
# Denmark            13.20
# EIRE               11.70
# France              3.35
# Germany             0.00
# Iceland            12.60
# Italy              17.00
# Japan               5.04
# Lithuania          13.20
# Norway              5.04
# Portugal            5.04
# Spain               0.42
# United Kingdom      0.00
# Name: total sales, dtype: float64
# Country
# Australia             71.40
# Channel Islands       50.00
# Denmark              183.60
# EIRE                 175.20
# France               171.80
# Germany              183.60
# Iceland               70.80
# Italy                 17.00
# Japan               3794.40
# Lithuania            122.40
# Norway                90.00
# Portugal             168.00
# Spain                 29.95
# United Kingdom     13541.33
# Name: total sales, dtype: float64
# Country
# Spain                174.72
# United Kingdom    319440.56
# Name: total sales, dtype: float64

# %%
country_four_min.plot(kind='bar')

plt.xlabel("country name")
plt.ylabel('values')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
df=pd.read_csv('/content/data - Copy.csv', encoding='latin1')
# Out:
# <ipython-input-37-24ba47db9ae8>:2: DtypeWarning: Columns (0,1,2,4,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/data - Copy.csv', encoding='latin1')

# %%
countrydf=df[df['Country'] == 'Australia']
print(countrydf)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 197       536389     22941         CHRISTMAS LIGHTS 10 REINDEER       6.0
# 198       536389     21622     VINTAGE UNION JACK CUSHION COVER       8.0
# 199       536389     21791   VINTAGE HEADS AND TAILS CARD GAME       12.0
# 200       536389    35004C      SET OF 3 COLOURED  FLYING DUCKS       6.0
# 201       536389    35004G           SET OF 3 GOLD FLYING DUCKS       4.0
# ...          ...       ...                                  ...       ...
# 497681    578459     22086      PAPER CHAIN KIT 50'S CHRISTMAS       20.0
# 497682    578459     22340           NOEL GARLAND PAINTED ZINC       24.0
# 497683    578459     22576  SWALLOW WOODEN CHRISTMAS DECORATION      20.0
# 497684    578459     22580         ADVENT CALENDAR GINGHAM SACK      12.0
# 497685    578459     22669                    RED BABY BUNTING       12.0
#
#        InvoiceDate      Time  UnitPrice  total sales  CustomerID    Country
# ...

# %%
print(countrydf.isnull().sum())
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Time           0
# UnitPrice      0
# total sales    0
# CustomerID     0
# Country        0
# dtype: int64

# %%
sales = countrydf['total sales'].sum()
print(sales)
# Out:
# 139965.35

# %%
import pandas as pd

# Read the data from the CSV file
df = pd.read_csv('/content/data - Copy.csv', encoding='latin1')


start_date = '12-01-2010'
end_date = '12-02-2010'
country = 'Australia'

custom_range_data = df[(df['InvoiceDate'] >= start_date) &
                       (df['InvoiceDate'] <= end_date) &
                       (df['Country'] == country)]


total_sales_one = custom_range_data['total sales'].sum()


print(f"Total sales for Australia from {start_date} to {end_date}: {total_sales_one}")
# Out:
# <ipython-input-62-49e5d8d5b64a>:6: DtypeWarning: Columns (0,1,2,4,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/data - Copy.csv', encoding='latin1')
# Total sales for Australia from 12-01-2010 to 12-02-2010: 358.25

# %%
df = pd.read_csv('/content/data - Copy.csv', encoding='latin1')


start_date = '01-02-2011'
end_date = '27-02-2011'
country = 'Australia'

custom_range_data = df[(df['InvoiceDate'] >= start_date) &
                       (df['InvoiceDate'] <= end_date) &
                       (df['Country'] == country)]


total_sales_two = custom_range_data['total sales'].sum()


print(f"Total sales for Australia from {start_date} to {end_date}: {total_sales_two}")
# Out:
# <ipython-input-67-6db109d7f545>:2: DtypeWarning: Columns (0,1,2,4,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/data - Copy.csv', encoding='latin1')
# Total sales for Australia from 01-02-2011 to 27-02-2011: 71759.23999999999

# %%
df = pd.read_csv('/content/data - Copy.csv', encoding='latin1')


start_date = '12-03-2010'
end_date = '12-04-2010'
country = 'Australia'

custom_range_data = df[(df['InvoiceDate'] >= start_date) &
                       (df['InvoiceDate'] <= end_date) &
                       (df['Country'] == country)]


total_sales_four = custom_range_data['total sales'].sum()


print(f"Total sales for Australia from {start_date} to {end_date}: {total_sales_four}")
# Out:
# <ipython-input-64-4718510e5980>:2: DtypeWarning: Columns (0,1,2,4,5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/data - Copy.csv', encoding='latin1')
# Total sales for Australia from 12-03-2010 to 12-04-2010: 0.0

# %%
datesales=df.groupby('InvoiceDate')['total sales'].sum().head(10)
print(datesales)
# Out:
# InvoiceDate
# 01-04-2011    17101.68
# 01-05-2011    66835.17
# 01-06-2011    43372.96
# 01-07-2011    30440.04
# 01-09-2011    15845.60
# 01-10-2011    24946.50
# 01-11-2011    69494.05
# 01-12-2011    25428.78
# 02-01-2011    29636.76
# 02-02-2011    21383.95
# Name: total sales, dtype: float64

# %%
import matplotlib.pyplot as plt
datesales.plot(kind='line')
plt.xlabel('InvoiceDate')
plt.ylabel('total sales')
plt.title('Line Graph of InvoiceDate vs total sales')
plt.xticks(rotation=90)
plt.show()

# %%
customer_retain = df.groupby(by=['Country', 'CustomerID','InvoiceDate'])[['Quantity']].count().sort_values(by='Quantity',ascending=False).head(50)
print(customer_retain)
# Out:
#                                        Quantity
# Country        CustomerID InvoiceDate
# United Kingdom 14096.0    11/14/2011        543
#                           11/28/2011        534
#                           12-05-2011        530
#                           11/23/2011        443
#                           10/31/2011        436
#                           9/21/2011         422
#                14769.0    9/18/2011         399
#                12748.0    11/23/2011        379
#                14096.0    11-10-2011        378
#                           10/17/2011        365
#                           10-10-2011        354
#                           10/24/2011        353
#                           9/26/2011         336
#                16549.0    11/29/2011        320
#                14769.0    3/20/2011         294
#                14096.0    10-03-2011        286
#                16984.0    08-01-2011        277
#                14769.0    5/22/2011         264
# ...

# %%
total_cr=df.groupby('Country')['CustomerID'].count()
print(total_cr)
# Out:
# Country
# Australia                 1259
# Austria                    401
# Bahrain                     17
# Belgium                   2069
# Brazil                      32
# Canada                     151
# Channel Islands            758
# Cyprus                     622
# Czech Republic              30
# Denmark                    389
# EIRE                      7485
# European Community          61
# Finland                    695
# France                    8491
# Germany                   9495
# Greece                     146
# Hong Kong                    0
# Iceland                    182
# Israel                     250
# Italy                      803
# Japan                      358
# Lebanon                     45
# Lithuania                   35
# Malta                      127
# Netherlands               2371
# Norway                    1086
# Poland                     341
# Portugal                  1480
# RSA                         58
# Saudi Arabia                10
# ...

# %%
valueCustomer = df.groupby(by=['Country', 'CustomerID','InvoiceDate'])[['total sales']].sum().sort_values(by='total sales',ascending=False).head(50)
print(valueCustomer)
# Out:
#                                        total sales
# Country        CustomerID InvoiceDate
# United Kingdom 16446.0    12-09-2011     336939.20
#                12346.0    1/18/2011      154367.20
#                15098.0    06-10-2011      79183.50
#                17450.0    9/20/2011       71601.44
#                15749.0    4/18/2011       44534.30
#                18102.0    9/15/2011       31661.54
#                           10/21/2011      29693.82
#                           12-07-2010      25920.37
# Netherlands    14646.0    10/20/2011      25833.56
# United Kingdom 16029.0    10-11-2011      23779.20
# Australia      12415.0    6/15/2011       23426.81
# United Kingdom 16029.0    05-03-2011      23215.50
#                15749.0    01-11-2011      22998.40
#                18102.0    10-03-2011      22429.69
# Australia      12415.0    8/18/2011       21880.44
# United Kingdom 17949.0    6/30/2011       20525.18
# Netherlands    14646.0    08-11-2011      19150.66
# ...

# %%
total_sales = df.groupby('Country')['total sales'].sum()
customer_count = df.groupby('Country')['CustomerID'].count()

revenue_percentage = (customer_count / total_sales) * 100

print(revenue_percentage)
# Out:
# Country
# Australia               0.899508
# Austria                 3.914853
# Bahrain                 1.771055
# Belgium                 4.987739
# Brazil                  2.798181
# Canada                  4.118504
# Channel Islands         3.641676
# Cyprus                  4.369674
# Czech Republic          3.172052
# Denmark                 2.032123
# EIRE                    2.465162
# European Community      4.660936
# Finland                 3.052876
# France                  3.824321
# Germany                 4.022690
# Greece                  3.035015
# Hong Kong               0.000000
# Iceland                 4.222738
# Israel                  2.989465
# Italy                   4.442362
# Japan                   0.906510
# Lebanon                 2.656623
# Lithuania               2.107088
# Malta                   4.311354
# Netherlands             0.828352
# Norway                  2.921914
# Poland                  4.573400
# Portugal                3.881745
# ...

# %%
import matplotlib.pyplot as plt
revenue_percentage.plot(kind='bar')
plt.xlabel('InvoiceDate')
plt.ylabel('total sales')
plt.title('Line Graph of InvoiceDate vs total sales')
plt.xticks(rotation=90)
plt.show()
